# %% [markdown]
# # Evaluating the performance of the CENTRE.MI.MSI consensus LcL classifier accross CT when using MI and MSI features from other cell types

# %% [markdown]
# In this case MI and MSI features are recomputed using IS and DI across CT

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np # calculate the mean and standard deviation
import xgboost as xgb # XGBoost stuff
from xgboost import plot_importance
from sklearn.model_selection import train_test_split # split  data into training and testing sets
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV # cross validation
from sklearn.metrics import confusion_matrix # creates a confusion matrix
#from sklearn.metrics import plot_confusion_matrix # draws a confusion matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import KFold, cross_val_score
from numpy import sort

# %%
#### Load the CENTRE.MI.MSI classifier
CENTREMIMSI = xgb.Booster()
CENTREMIMSI.load_model("/home/lopez_s/CRUP_scores/CENTRE_HiC/Training/CENTRE_HiC_classifiers/consensusLcL10kb_model.txt")

# %%
##General paths and suffixes
suffixMIMSI = "-Benchmark.MI.MSI.v38.csv"
suffixBENGI = "-Benchmark.v38.txt"
rootMIMSI = "/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_datasets/10Kb/"
rootBENGI = "/project/CRUP_scores/toSara/BENGI_processed_datasets/"

# %%
sample = "consensusLcL"
consensusLcLMSIMI = pd.read_csv(rootMIMSI+sample+suffixMIMSI, 
                 header=0, sep=',')

# %%
print(list(consensusLcLMSIMI))
# Out:
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']

# %%
consensusLcLMSIMI = consensusLcLMSIMI.drop_duplicates('pair19')
com=consensusLcLMSIMI.fillna(0)
#From the analysis coming from the master Thesis we found these to be the best parameters for the consensusLcL CENTREMI.MSI model
best_params = {'subsample': 0.9, 'reg_lambda': 0, 'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 1.0, 'colsample_bytree': 0.9}

# %%
def CVF1results(com, best_params, test):

    cv_names=com["CV"].unique()
    d = dict(tuple(com.groupby('CV')))
    dtest = dict(tuple(test.groupby('CV')))
    result_all_xgboost={}
    result_all_tf={}
    result_cv_xg=[]
    result_cv_tf=[]
    for i in range(len(cv_names)):
        cv_test=cv_names[i]
        print(cv_test)
        cv_train=[x for k,x in enumerate(cv_names) if k!=i]
        print(cv_train)
        print(dtest.keys())
        X_test_xg = dtest[cv_test].drop(['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'CV'], axis=1).copy()
        y_test_xg = dtest[cv_test]['label'].copy()
        train_xg=pd.concat({k: d[k] for k in cv_train})
        X_train_xg= train_xg.drop(['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'CV'], axis=1).copy()
        y_train_xg = train_xg['label'].copy()
        clf_xgb = xgb.XGBClassifier(objective = "binary:logistic",scale_pos_weight=5,random_state=0,**best_params)
        clf_xgb.fit(X_train_xg, y_train_xg)
        pred_s = clf_xgb.predict_proba(X_test_xg)
        lr_probs =pred_s[:, 1]
        yhat = clf_xgb.predict(X_test_xg)
        result_cv = pd.DataFrame({'pred_prob':lr_probs,'pred_label': yhat,'true_label':y_test_xg})
        result_cv_xg.append(f1_score(result_cv['true_label'], result_cv['pred_label']))
        result_all_xgboost[cv_test]=result_cv
        



    results_xg=pd.concat(result_all_xgboost)
    
    lr_precision_xg, lr_recall_xg, _ = precision_recall_curve(results_xg['true_label'], results_xg['pred_prob'])
    lr_f1_xg, lr_auc_xg = f1_score(results_xg['true_label'], results_xg['pred_label']), auc(lr_recall_xg, lr_precision_xg)
    print('xgboost HiC 12 fold CV:auc=%.3f' % lr_auc_xg)
    print(lr_f1_xg)
    print(result_cv_xg)

    dist_precision, dist_recall, _=precision_recall_curve(com['label'],1/abs(com['distance']))
    dist_auc = auc(dist_recall, dist_precision)
    print('Distance:auc=%.3f' % (dist_auc))
    return(lr_f1_xg, result_cv_xg)

# %%
pathtometadata = "/project/CRUP_scores/CENTRE_HiC/AcrossCTComparisonMSIMI/AcrossCTMetadata.csv"
metadata = pd.read_csv(pathtometadata, 
                         header=0, sep=',')
print(metadata['JoinedName'])
# Out:
# 0                  Colon.GTEx-ovary
# 1               Colon.GTEx-pancreas
# 2                Colon.GTEx-stomach
# 3          Ovary.GTEx-sigmoid-colon
# 4                  Ovary.GTEx-ovary
# 5               Ovary.GTEx-pancreas
# 6                Ovary.GTEx-stomach
# 7       Pancreas.GTEx-sigmoid-colon
# 8               Pancreas.GTEx-ovary
# 9            Pancreas.GTEx-pancreas
# 10            Pancreas.GTEx-stomach
# 11       Stomach.GTEx-sigmoid-colon
# 12               Stomach.GTEx-ovary
# 13            Stomach.GTEx-pancreas
# 14             Stomach.GTEx-stomach
# 15              GM12878.CHiC-IMR-90
# 16                GM12878.CHiC-K562
# 17      GM12878.CTCF-ChIAPET-IMR-90
# 18        GM12878.CTCF-ChIAPET-K562
# 19          GM12878.GEUVADIS-IMR-90
# 20            GM12878.GEUVADIS-K562
# 21               GM12878.HiC-IMR-90
# 22                 GM12878.HiC-K562
# 23    GM12878.RNAPII-ChIAPET-IMR-90
# 24      GM12878.RNAPII-ChIAPET-K562
# 25                IMR90.HiC-GM12878
# 26                 IMR90.HiC-IMR-90
# 27                   IMR90.HiC-K562
# 28              K562.CRISPR-GM12878
# 29               K562.CRISPR-IMR-90
# 30                 K562.HiC-GM12878
# 31                  K562.HiC-IMR-90
# Name: JoinedName, dtype: object

# %%
##calculate F1 for mixed CT benchmarks
pathBenchmark = "/project/CRUP_scores/CENTRE_HiC/AcrossCTComparisonMSIMI/BENGI_MI_MSI_acrossCT/"
f1data = pd.DataFrame(columns = ["SampleBENGI","SampleMSIMI", "F1_Score_MIMSI", "NumRows"])

for sample in metadata['JoinedName']:
    test = pd.read_csv(pathBenchmark+
                       sample +
                       '.MIMSI.csv', 
                         header=0, sep=',')
    print(list(test))
    test=test.fillna(0)
    test['distance'] =test['distance'].abs()
    lr_f1, resultcv  = CVF1results(com, best_params, test)
    numrows = len(test)
    #Dataframe for the current sample  
    f1data1 = pd.DataFrame()
    f1data1['Sample'] = [sample]*12
    f1data1['F1_Score_MIMSI'] = resultcv
    f1data1['NumRows'] = [numrows]*12
    # Concatenate with big dataframe
    print(f1data1)
    f1data1.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/CENTRE_final_training/F1scoresAcrossCT/' +
                   sample +
                   '_f1scores.csv')
    f1data = pd.concat([f1data, f1data1], ignore_index = True)
            

f1data.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/CENTRE_final_training/F1scoresAcrossCT/F1scoresAllCT.csv')
# Out:
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.172
# 0.2651988991743808
# [0.30868167202572344, 0.34934497816593885, 0.21379310344827587, 0.25352112676056343, 0.23178807947019872, 0.24543080939947784, 0.24274406332453824, 0.22873900293255134, 0.1979381443298969, 0.32142857142857145, 0.3402777777777778, 0.3223140495867769]
# Distance:auc=0.197
#               Sample  F1_Score_MIMSI  NumRows
# 0   Colon.GTEx-ovary        0.308682    26983
# 1   Colon.GTEx-ovary        0.349345    26983
# 2   Colon.GTEx-ovary        0.213793    26983
# 3   Colon.GTEx-ovary        0.253521    26983
# 4   Colon.GTEx-ovary        0.231788    26983
# 5   Colon.GTEx-ovary        0.245431    26983
# 6   Colon.GTEx-ovary        0.242744    26983
# 7   Colon.GTEx-ovary        0.228739    26983
# 8   Colon.GTEx-ovary        0.197938    26983
# 9   Colon.GTEx-ovary        0.321429    26983
# 10  Colon.GTEx-ovary        0.340278    26983
# 11  Colon.GTEx-ovary        0.322314    26983
# /scratch/local/ipykernel_94687/4221373940.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   f1data = pd.concat([f1data, f1data1], ignore_index = True)
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.172
# 0.26703545385969324
# [0.3102310231023102, 0.34977578475336324, 0.23157894736842105, 0.24649859943977587, 0.23920265780730895, 0.24933687002652516, 0.23918575063613232, 0.23976608187134502, 0.2028397565922921, 0.3204134366925065, 0.32974910394265233, 0.3291139240506329]
# Distance:auc=0.197
#                  Sample  F1_Score_MIMSI  NumRows
# 0   Colon.GTEx-pancreas        0.310231    26983
# 1   Colon.GTEx-pancreas        0.349776    26983
# 2   Colon.GTEx-pancreas        0.231579    26983
# 3   Colon.GTEx-pancreas        0.246499    26983
# 4   Colon.GTEx-pancreas        0.239203    26983
# 5   Colon.GTEx-pancreas        0.249337    26983
# 6   Colon.GTEx-pancreas        0.239186    26983
# 7   Colon.GTEx-pancreas        0.239766    26983
# 8   Colon.GTEx-pancreas        0.202840    26983
# 9   Colon.GTEx-pancreas        0.320413    26983
# 10  Colon.GTEx-pancreas        0.329749    26983
# 11  Colon.GTEx-pancreas        0.329114    26983
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.172
# 0.2651685393258427
# [0.3157894736842105, 0.32286995515695066, 0.22695035460992907, 0.25274725274725274, 0.23920265780730895, 0.24607329842931938, 0.23437499999999997, 0.23931623931623933, 0.20120724346076457, 0.3206106870229008, 0.33215547703180204, 0.32365145228215764]
# Distance:auc=0.197
#                 Sample  F1_Score_MIMSI  NumRows
# 0   Colon.GTEx-stomach        0.315789    26983
# 1   Colon.GTEx-stomach        0.322870    26983
# 2   Colon.GTEx-stomach        0.226950    26983
# 3   Colon.GTEx-stomach        0.252747    26983
# 4   Colon.GTEx-stomach        0.239203    26983
# 5   Colon.GTEx-stomach        0.246073    26983
# 6   Colon.GTEx-stomach        0.234375    26983
# 7   Colon.GTEx-stomach        0.239316    26983
# 8   Colon.GTEx-stomach        0.201207    26983
# 9   Colon.GTEx-stomach        0.320611    26983
# 10  Colon.GTEx-stomach        0.332155    26983
# 11  Colon.GTEx-stomach        0.323651    26983
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.152
# 0.24517287831163
# [0.1982758620689655, 0.3575418994413408, 0.19387755102040818, 0.28260869565217395, 0.2690058479532164, 0.21524663677130043, 0.251497005988024, 0.20289855072463767, 0.3216783216783217, 0.21100917431192664, 0.29457364341085274, 0.22018348623853212]
# Distance:auc=0.197
#                       Sample  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx-sigmoid-colon        0.198276    13789
# 1   Ovary.GTEx-sigmoid-colon        0.357542    13789
# 2   Ovary.GTEx-sigmoid-colon        0.193878    13789
# 3   Ovary.GTEx-sigmoid-colon        0.282609    13789
# 4   Ovary.GTEx-sigmoid-colon        0.269006    13789
# 5   Ovary.GTEx-sigmoid-colon        0.215247    13789
# 6   Ovary.GTEx-sigmoid-colon        0.251497    13789
# 7   Ovary.GTEx-sigmoid-colon        0.202899    13789
# 8   Ovary.GTEx-sigmoid-colon        0.321678    13789
# 9   Ovary.GTEx-sigmoid-colon        0.211009    13789
# 10  Ovary.GTEx-sigmoid-colon        0.294574    13789
# 11  Ovary.GTEx-sigmoid-colon        0.220183    13789
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.152
# 0.24272279444693237
# [0.19047619047619047, 0.3535911602209945, 0.20304568527918782, 0.2717391304347826, 0.27380952380952384, 0.20535714285714288, 0.2634730538922156, 0.2007168458781362, 0.304635761589404, 0.21395348837209308, 0.28346456692913385, 0.22018348623853212]
# Distance:auc=0.197
#               Sample  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx-ovary        0.190476    13789
# 1   Ovary.GTEx-ovary        0.353591    13789
# 2   Ovary.GTEx-ovary        0.203046    13789
# 3   Ovary.GTEx-ovary        0.271739    13789
# 4   Ovary.GTEx-ovary        0.273810    13789
# 5   Ovary.GTEx-ovary        0.205357    13789
# 6   Ovary.GTEx-ovary        0.263473    13789
# 7   Ovary.GTEx-ovary        0.200717    13789
# 8   Ovary.GTEx-ovary        0.304636    13789
# 9   Ovary.GTEx-ovary        0.213953    13789
# 10  Ovary.GTEx-ovary        0.283465    13789
# 11  Ovary.GTEx-ovary        0.220183    13789
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.154
# 0.24808988764044942
# [0.1896551724137931, 0.3575418994413408, 0.20304568527918782, 0.27624309392265195, 0.2807017543859649, 0.21524663677130043, 0.26993865030674846, 0.19928825622775798, 0.3165467625899281, 0.22522522522522523, 0.3125, 0.22018348623853212]
# Distance:auc=0.197
#                  Sample  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx-pancreas        0.189655    13789
# 1   Ovary.GTEx-pancreas        0.357542    13789
# 2   Ovary.GTEx-pancreas        0.203046    13789
# 3   Ovary.GTEx-pancreas        0.276243    13789
# 4   Ovary.GTEx-pancreas        0.280702    13789
# 5   Ovary.GTEx-pancreas        0.215247    13789
# 6   Ovary.GTEx-pancreas        0.269939    13789
# 7   Ovary.GTEx-pancreas        0.199288    13789
# 8   Ovary.GTEx-pancreas        0.316547    13789
# 9   Ovary.GTEx-pancreas        0.225225    13789
# 10  Ovary.GTEx-pancreas        0.312500    13789
# 11  Ovary.GTEx-pancreas        0.220183    13789
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.153
# 0.24843049327354258
# [0.20600858369098712, 0.3626373626373627, 0.2233502538071066, 0.27472527472527475, 0.2543352601156069, 0.21428571428571427, 0.251497005988024, 0.2007168458781362, 0.3120567375886525, 0.22727272727272727, 0.304, 0.22429906542056072]
# Distance:auc=0.197
#                 Sample  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx-stomach        0.206009    13789
# 1   Ovary.GTEx-stomach        0.362637    13789
# 2   Ovary.GTEx-stomach        0.223350    13789
# 3   Ovary.GTEx-stomach        0.274725    13789
# 4   Ovary.GTEx-stomach        0.254335    13789
# 5   Ovary.GTEx-stomach        0.214286    13789
# 6   Ovary.GTEx-stomach        0.251497    13789
# 7   Ovary.GTEx-stomach        0.200717    13789
# 8   Ovary.GTEx-stomach        0.312057    13789
# 9   Ovary.GTEx-stomach        0.227273    13789
# 10  Ovary.GTEx-stomach        0.304000    13789
# 11  Ovary.GTEx-stomach        0.224299    13789
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.204
# 0.29114425234261576
# [0.2975206611570248, 0.37446808510638296, 0.22606382978723405, 0.296969696969697, 0.3018867924528302, 0.3333333333333333, 0.22695035460992907, 0.30638297872340425, 0.24417314095449502, 0.32754342431761785, 0.33613445378151263, 0.3315315315315316]
# Distance:auc=0.197
#                          Sample  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx-sigmoid-colon        0.297521    43357
# 1   Pancreas.GTEx-sigmoid-colon        0.374468    43357
# 2   Pancreas.GTEx-sigmoid-colon        0.226064    43357
# 3   Pancreas.GTEx-sigmoid-colon        0.296970    43357
# 4   Pancreas.GTEx-sigmoid-colon        0.301887    43357
# 5   Pancreas.GTEx-sigmoid-colon        0.333333    43357
# 6   Pancreas.GTEx-sigmoid-colon        0.226950    43357
# 7   Pancreas.GTEx-sigmoid-colon        0.306383    43357
# 8   Pancreas.GTEx-sigmoid-colon        0.244173    43357
# 9   Pancreas.GTEx-sigmoid-colon        0.327543    43357
# 10  Pancreas.GTEx-sigmoid-colon        0.336134    43357
# 11  Pancreas.GTEx-sigmoid-colon        0.331532    43357
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.204
# 0.2907314496963296
# [0.28758169934640526, 0.38477801268498935, 0.22721268163804487, 0.2961832061068702, 0.30998509687034276, 0.3333333333333333, 0.22508792497069166, 0.29650349650349656, 0.24776785714285712, 0.33415233415233414, 0.3299319727891156, 0.33034111310592457]
# Distance:auc=0.197
#                  Sample  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx-ovary        0.287582    43357
# 1   Pancreas.GTEx-ovary        0.384778    43357
# 2   Pancreas.GTEx-ovary        0.227213    43357
# 3   Pancreas.GTEx-ovary        0.296183    43357
# 4   Pancreas.GTEx-ovary        0.309985    43357
# 5   Pancreas.GTEx-ovary        0.333333    43357
# 6   Pancreas.GTEx-ovary        0.225088    43357
# 7   Pancreas.GTEx-ovary        0.296503    43357
# 8   Pancreas.GTEx-ovary        0.247768    43357
# 9   Pancreas.GTEx-ovary        0.334152    43357
# 10  Pancreas.GTEx-ovary        0.329932    43357
# 11  Pancreas.GTEx-ovary        0.330341    43357
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.202
# 0.2912234042553191
# [0.28618968386023297, 0.3736730360934183, 0.2231182795698925, 0.29906542056074764, 0.3170731707317073, 0.34430379746835443, 0.22405660377358494, 0.30617977528089885, 0.24309392265193372, 0.32673267326732675, 0.32377740303541314, 0.3424408014571949]
# Distance:auc=0.197
#                     Sample  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx-pancreas        0.286190    43357
# 1   Pancreas.GTEx-pancreas        0.373673    43357
# 2   Pancreas.GTEx-pancreas        0.223118    43357
# 3   Pancreas.GTEx-pancreas        0.299065    43357
# 4   Pancreas.GTEx-pancreas        0.317073    43357
# 5   Pancreas.GTEx-pancreas        0.344304    43357
# 6   Pancreas.GTEx-pancreas        0.224057    43357
# 7   Pancreas.GTEx-pancreas        0.306180    43357
# 8   Pancreas.GTEx-pancreas        0.243094    43357
# 9   Pancreas.GTEx-pancreas        0.326733    43357
# 10  Pancreas.GTEx-pancreas        0.323777    43357
# 11  Pancreas.GTEx-pancreas        0.342441    43357
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.203
# 0.2917440934430582
# [0.294314381270903, 0.3811563169164882, 0.2275132275132275, 0.2961832061068702, 0.3109118086696562, 0.34096692111959287, 0.22429906542056072, 0.30140845070422534, 0.25140291806958476, 0.3225806451612903, 0.32432432432432434, 0.33823529411764713]
# Distance:auc=0.197
#                    Sample  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx-stomach        0.294314    43357
# 1   Pancreas.GTEx-stomach        0.381156    43357
# 2   Pancreas.GTEx-stomach        0.227513    43357
# 3   Pancreas.GTEx-stomach        0.296183    43357
# 4   Pancreas.GTEx-stomach        0.310912    43357
# 5   Pancreas.GTEx-stomach        0.340967    43357
# 6   Pancreas.GTEx-stomach        0.224299    43357
# 7   Pancreas.GTEx-stomach        0.301408    43357
# 8   Pancreas.GTEx-stomach        0.251403    43357
# 9   Pancreas.GTEx-stomach        0.322581    43357
# 10  Pancreas.GTEx-stomach        0.324324    43357
# 11  Pancreas.GTEx-stomach        0.338235    43357
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.164
# 0.26827985270910043
# ...
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.320
# 0.38434163701067614
# [0.3835616438356164, 0.31395348837209297, 0.4938271604938271, 0.48529411764705876, 0.5106382978723404, 0.5274725274725274, 0.18867924528301888, 0.5510204081632653, 0.41509433962264153, 0.49056603773584895, 0.13793103448275865, 0.3064516129032258]
# Distance:auc=0.197
#                  Sample  F1_Score_MIMSI  NumRows
# 0   K562.CRISPR-GM12878        0.383562    13961
# 1   K562.CRISPR-GM12878        0.313953    13961
# 2   K562.CRISPR-GM12878        0.493827    13961
# 3   K562.CRISPR-GM12878        0.485294    13961
# 4   K562.CRISPR-GM12878        0.510638    13961
# 5   K562.CRISPR-GM12878        0.527473    13961
# 6   K562.CRISPR-GM12878        0.188679    13961
# 7   K562.CRISPR-GM12878        0.551020    13961
# 8   K562.CRISPR-GM12878        0.415094    13961
# 9   K562.CRISPR-GM12878        0.490566    13961
# 10  K562.CRISPR-GM12878        0.137931    13961
# 11  K562.CRISPR-GM12878        0.306452    13961
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.304
# 0.37550471063257074
# [0.35294117647058826, 0.27027027027027023, 0.4835164835164835, 0.4671532846715329, 0.4999999999999999, 0.5052631578947369, 0.2105263157894737, 0.5656565656565655, 0.3793103448275862, 0.5789473684210527, 0.11999999999999998, 0.303030303030303]
# Distance:auc=0.197
#                 Sample  F1_Score_MIMSI  NumRows
# 0   K562.CRISPR-IMR-90        0.352941    13961
# 1   K562.CRISPR-IMR-90        0.270270    13961
# 2   K562.CRISPR-IMR-90        0.483516    13961
# 3   K562.CRISPR-IMR-90        0.467153    13961
# 4   K562.CRISPR-IMR-90        0.500000    13961
# 5   K562.CRISPR-IMR-90        0.505263    13961
# 6   K562.CRISPR-IMR-90        0.210526    13961
# 7   K562.CRISPR-IMR-90        0.565657    13961
# 8   K562.CRISPR-IMR-90        0.379310    13961
# 9   K562.CRISPR-IMR-90        0.578947    13961
# 10  K562.CRISPR-IMR-90        0.120000    13961
# 11  K562.CRISPR-IMR-90        0.303030    13961
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.121
# 0.19769727604605447
# [0.30196936542669583, 0.21958456973293772, 0.30414746543778803, 0.13658536585365855, 0.2236024844720497, 0.1691176470588235, 0.18493150684931509, 0.10344827586206896, 0.2925170068027211, 0.1019108280254777, 0.1596009975062344, 0.16730038022813687]
# Distance:auc=0.197
#               Sample  F1_Score_MIMSI  NumRows
# 0   K562.HiC-GM12878        0.301969    27079
# 1   K562.HiC-GM12878        0.219585    27079
# 2   K562.HiC-GM12878        0.304147    27079
# 3   K562.HiC-GM12878        0.136585    27079
# 4   K562.HiC-GM12878        0.223602    27079
# 5   K562.HiC-GM12878        0.169118    27079
# 6   K562.HiC-GM12878        0.184932    27079
# 7   K562.HiC-GM12878        0.103448    27079
# 8   K562.HiC-GM12878        0.292517    27079
# 9   K562.HiC-GM12878        0.101911    27079
# 10  K562.HiC-GM12878        0.159601    27079
# 11  K562.HiC-GM12878        0.167300    27079
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.121
# 0.19766494705403204
# [0.3063063063063063, 0.2163588390501319, 0.29357798165137616, 0.16822429906542055, 0.20238095238095238, 0.19305019305019308, 0.1727574750830565, 0.09340659340659341, 0.28965517241379307, 0.09883720930232558, 0.16972477064220184, 0.18045112781954886]
# Distance:auc=0.197
#              Sample  F1_Score_MIMSI  NumRows
# 0   K562.HiC-IMR-90        0.306306    27079
# 1   K562.HiC-IMR-90        0.216359    27079
# 2   K562.HiC-IMR-90        0.293578    27079
# 3   K562.HiC-IMR-90        0.168224    27079
# 4   K562.HiC-IMR-90        0.202381    27079
# 5   K562.HiC-IMR-90        0.193050    27079
# 6   K562.HiC-IMR-90        0.172757    27079
# 7   K562.HiC-IMR-90        0.093407    27079
# 8   K562.HiC-IMR-90        0.289655    27079
# 9   K562.HiC-IMR-90        0.098837    27079
# 10  K562.HiC-IMR-90        0.169725    27079
# 11  K562.HiC-IMR-90        0.180451    27079

# %%
f1data.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/CENTRE_final_training/f1_consensusLcL.csv')

# %%
test = pd.read_csv('/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/'
                   "Colon.GTEx"+
                   'BENGI_'+
                   "GM12878.HiC"+
                   'MIMSI.csv', 
                   header=0, sep=' ')
print((list(test)))
# Out:
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y']
