# %% [markdown]
# # Evaluating the performance of the CENTRE.MI.MSI consensus LcL classifier accross CT when using MI and MSI features from other cell types

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np # calculate the mean and standard deviation
import xgboost as xgb # XGBoost stuff
from xgboost import plot_importance
from sklearn.model_selection import train_test_split # split  data into training and testing sets
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV # cross validation
from sklearn.metrics import confusion_matrix # creates a confusion matrix
#from sklearn.metrics import plot_confusion_matrix # draws a confusion matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import KFold, cross_val_score
from numpy import sort

# %%
#### Load the CENTRE.MI.MSI classifier
CENTREMIMSI = xgb.Booster()
CENTREMIMSI.load_model("/home/lopez_s/CRUP_scores/CENTRE_HiC/Training/CENTRE_HiC_classifiers/consensusLcL10kb_model.txt")

# %%
##General paths and suffixes
suffixMIMSI = "-Benchmark.MI.MSI.v38.csv"
suffixBENGI = "-Benchmark.v38.txt"
rootMIMSI = "/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_datasets/10Kb/"
rootBENGI = "/project/CRUP_scores/toSara/BENGI_processed_datasets/"

# %%
sample = "consensusLcL"
consensusLcLMSIMI = pd.read_csv(rootMIMSI+sample+suffixMIMSI, 
                 header=0, sep=',')

# %%
print(list(consensusLcLMSIMI))
# Out:
# ['pair', 'gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity']

# %%
consensusLcLMSIMI = consensusLcLMSIMI.drop_duplicates('pair19')
com=consensusLcLMSIMI.fillna(0)
#From the analysis coming from the master Thesis we found these to be the best parameters for the consensusLcL CENTREMI.MSI model
best_params = {'subsample': 0.9, 'reg_lambda': 0, 'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 1.0, 'colsample_bytree': 0.9}

# %%
#Lists containing the samples for which we have BENGI data sets (this means data set without Hic) and the samples for which we have hic

samplelisthic = ["Colon.GTEx", "GM12878.CHiC", "GM12878.CTCF-ChIAPET", "GM12878.GEUVADIS", "GM12878.HiC", "GM12878.RNAPII-ChIAPET",
                  "IMR90.HiC", "K562.CRISPR", "K562.HiC", "Ovary.GTEx", "Pancreas.GTEx", "Stomach.GTEx"]

samplelistbengi = ["Colon.GTEx", "GM12878.CHiC", "GM12878.CTCF-ChIAPET", "GM12878.GEUVADIS", "GM12878.HiC", "GM12878.RNAPII-ChIAPET",
                  "IMR90.HiC", "K562.CRISPR", "K562.HiC", "Ovary.GTEx", "Pancreas.GTEx", "Stomach.GTEx", "Liver.GTEx", "NHEK.HiC", 
                  "HeLa.CTCF-ChIAPET", "HeLa.HiC", "HeLa.RNAPII-ChIAPET"]

# %%
##WARNING: only run once
for samplebengi in samplelistbengi:
    for samplehic in samplelisthic:
        if samplebengi != samplehic :
            bengi = pd.read_csv(rootBENGI+samplebengi+suffixBENGI, 
                         header=0, sep='\t')
            bengi = bengi.drop_duplicates('pair19')
            print("Length of bengi is:", len(bengi))
            MSIMI = pd.read_csv(rootMIMSI+samplehic+suffixMIMSI, 
                         header=0, sep=',')
            MSIMI = MSIMI.drop_duplicates('pair19')
            MSIMI = MSIMI[['pair', 'min_insulation', 'mean_switch_intensity']]
            print("Length of hic is:", len(MSIMI))
            test = pd.merge(bengi, MSIMI, how="inner", on="pair")
            
            print("Length of test is:", len(test))
            test.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/
# Length of test is: 65
# Length of bengi is: 33392
# Length of hic is: 43357
# Length of test is: 560
# Length of bengi is: 33392
# Length of hic is: 35857
# Length of test is: 617
# Length of bengi is: 4791
# Length of hic is: 26983
# Length of test is: 177
# Length of bengi is: 4791
# Length of hic is: 283632
# Length of test is: 1037
# Length of bengi is: 4791
# Length of hic is: 80965
# Length of test is: 666
# Length of bengi is: 4791
# Length of hic is: 43288
# Length of test is: 102
# Length of bengi is: 4791
# Length of hic is: 35189
# Length of test is: 84
# Length of bengi is: 4791
# Length of hic is: 116429
# Length of test is: 1114
# Length of bengi is: 4791
# Length of hic is: 25564
# Length of test is: 188
# Length of bengi is: 4791
# Length of hic is: 13961
# Length of test is: 228
# Length of bengi is: 4791
# Length of hic is: 27079
# Length of test is: 238
# Length of bengi is: 4791
# Length of hic is: 13789
# Length of test is: 64
# Length of bengi is: 4791
# Length of hic is: 43357
# Length of test is: 218
# Length of bengi is: 4791
# Length of hic is: 35857
# Length of test is: 241

# %%
# since the sizes of the datasets have changed we need to reassign the cv folds
## Taken from BENGI github https://github.com/weng-lab/BENGI/blob/master/Scripts/Generate-Benchmark/assign.groups.py
## The code is adapted

##More general determination of groups. 
def Determine_Groups(chromDict):
    chromArray=[]
    groupDict={}
    for key, value in sorted(chromDict.items(), key=lambda x:x[1]):
        chromArray.append(key)
    print(chromArray)
    numtwo = len(chromArray) % 12
    res = 12 - numtwo
    for i in range(0,numtwo):
        groupDict[chromArray[i]]="cv-"+str(i)
        groupDict[chromArray[-res-i]]="cv-"+str(i)
    if numtwo != 11:
        for i in range(numtwo, 11):
            groupDict[chromArray[i]]="cv-"+str(i)
    groupDict[chromArray[-1]]="cv-11"
    return groupDict

def Create_Chrom_Dict(enhancers):
    chromDict={}
    enhancerDict={}
    for line in enhancers:
        line=line.rstrip().split(" ")
        #skip the header
        if line[38] == "chr.y":
            print(line)
            continue
        line[38]=line[38].rstrip()
        if line[38] not in chromDict:
            chromDict[line[38]]=1
        else:
            chromDict[line[38]]+=1
        if line[2].rstrip() not in enhancerDict:
            enhancerDict[line[2].rstrip()]=line[38]
    return chromDict, enhancerDict

def CVmaker(enhancerspath):
    enhancers=open(enhancerspath)
    chromDict, enhancerDict = Create_Chrom_Dict(enhancers)
    enhancers.close()
    groupDict=Determine_Groups(chromDict)
    sizecvdict = {}
    seenchroms = []
    for key, value in groupDict.items():
        if value not in sizecvdict:
            sizecvdict[value] = chromDict[key]
            seenchroms.append(key)
        if value in sizecvdict and key not in seenchroms : 
            sizecvdict[value] += chromDict[key]
    return chromDict, enhancerDict, groupDict, sizecvdict

# %%
def CVF1results(com, best_params, test):

    cv_names=com["CV"].unique()
    d = dict(tuple(com.groupby('CV')))
    dtest = dict(tuple(test.groupby('CV')))
    result_all_xgboost={}
    result_all_tf={}
    result_cv_xg=[]
    result_cv_tf=[]
    for i in range(len(cv_names)):
        cv_test=cv_names[i]
        print(cv_test)
        cv_train=[x for k,x in enumerate(cv_names) if k!=i]
        print(cv_train)
        print(dtest.keys())
        X_test_xg = dtest[cv_test].drop(['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'CV', 'CVnew', 'chr.x', 'chr.y'], axis=1).copy()
        y_test_xg = dtest[cv_test]['label'].copy()
        train_xg=pd.concat({k: d[k] for k in cv_train})
        X_train_xg= train_xg.drop(['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'CV'], axis=1).copy()
        y_train_xg = train_xg['label'].copy()
        clf_xgb = xgb.XGBClassifier(objective = "binary:logistic",scale_pos_weight=5,random_state=0,**best_params)
        clf_xgb.fit(X_train_xg, y_train_xg)
        pred_s = clf_xgb.predict_proba(X_test_xg)
        lr_probs =pred_s[:, 1]
        yhat = clf_xgb.predict(X_test_xg)
        result_cv = pd.DataFrame({'pred_prob':lr_probs,'pred_label': yhat,'true_label':y_test_xg})
        result_cv_xg.append(f1_score(result_cv['true_label'], result_cv['pred_label']))
        result_all_xgboost[cv_test]=result_cv
        



    results_xg=pd.concat(result_all_xgboost)
    
    lr_precision_xg, lr_recall_xg, _ = precision_recall_curve(results_xg['true_label'], results_xg['pred_prob'])
    lr_f1_xg, lr_auc_xg = f1_score(results_xg['true_label'], results_xg['pred_label']), auc(lr_recall_xg, lr_precision_xg)
    print('xgboost HiC 12 fold CV:auc=%.3f' % lr_auc_xg)
    print(lr_f1_xg)
    print(result_cv_xg)

    dist_precision, dist_recall, _=precision_recall_curve(com['label'],1/abs(com['distance']))
    dist_auc = auc(dist_recall, dist_precision)
    print('Distance:auc=%.3f' % (dist_auc))
    return(lr_f1_xg, result_cv_xg)

# %%
##Separate cell lines and tissues
## This is only tissues
samplelisthictissue = ["Colon.GTEx", "Ovary.GTEx", "Pancreas.GTEx", "Stomach.GTEx"]
samplelistbengitissue = ["Colon.GTEx", "Ovary.GTEx", "Pancreas.GTEx", "Stomach.GTEx", "Liver.GTEx"]

# %%
for samplebengi in samplelistbengitissue:
    for samplehic in samplelisthictissue:
        if samplebengi != samplehic :
            print(samplebengi, samplehic)
            test = pd.read_csv('/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/'+
                               samplebengi +
                               'BENGI_'
                               + samplehic
                               + 'MIMSI.csv', 
                         header=0, sep=' ')
            print(len(set(test["chr.x"])))
            path = '/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/'+samplebengi+'BENGI_'+ samplehic+ 'MIMSI.csv'
            chromDict, enhancerDict, groupDict, sizecvdict = CVmaker(path)
            #remove old CV column to fill it with new CV indexes
            print(sizecvdict)
            print(groupDict)
            print(chromDict)
            test = test.drop(['CV'], axis=1)    
            test['CV'] = test['chr.x'].map(groupDict)
    
            test.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/'+ samplebengi + 'BENGI_' + samplehic+ 'MIMSI.csv', 
                            index = False,
                           sep = " ")
# Out:
# Colon.GTEx Ovary.GTEx
# 18
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# ['chr8', 'chr12', 'chr18', 'chr2', 'chr4', 'chr5', 'chr22', 'chr1', 'chr9', 'chr6', 'chr7', 'chr15', 'chr19', 'chr10', 'chr3', 'chr16', 'chr11', 'chr17']
# {'cv-0': 88, 'cv-1': 90, 'cv-2': 17, 'cv-10': 61, 'cv-3': 22, 'cv-9': 47, 'cv-4': 23, 'cv-8': 37, 'cv-5': 28, 'cv-7': 37, 'cv-6': 34, 'cv-11': 221}
# {'chr12': 'cv-0', 'chr1': 'cv-10', 'chr8': 'cv-1', 'chr19': 'cv-9', 'chr9': 'cv-2', 'chr3': 'cv-8', 'chr2': 'cv-3', 'chr6': 'cv-7', 'chr22': 'cv-4', 'chr14': 'cv-6', 'chr4': 'cv-5', 'chr16': 'cv-11'}
# {'chr17': 194, 'chr3': 57, 'chr7': 85, 'chr16': 221, 'chr19': 75, 'chr6': 54, 'chr2': 29, 'chr11': 120, 'chr1': 83, 'chr10': 119, 'chr9': 20, 'chr4': 38, 'chr22': 34, 'chr14': 39, 'chr15': 85, 'chr12': 2, 'chr8': 2}
# Pancreas.GTEx Colon.GTEx
# 21
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# ['chr21', 'chr14', 'chr9', 'chr5', 'chr8', 'chr12', 'chrX', 'chr20', 'chr4', 'chr10', 'chr15', 'chr3', 'chr7', 'chr2', 'chr19', 'chr6', 'chr1', 'chr22', 'chr17', 'chr16', 'chr11']
# {'cv-0': 596, 'cv-1': 573, 'cv-2': 455, 'cv-3': 425, 'cv-4': 424, 'cv-5': 407, 'cv-6': 374, 'cv-7': 353, 'cv-8': 97, 'cv-10': 221, 'cv-9': 163, 'cv-11': 753}
# {'chr21': 'cv-0', 'chr17': 'cv-0', 'chr14': 'cv-1', 'chr22': 'cv-1', 'chr9': 'cv-2', 'chr1': 'cv-2', 'chr5': 'cv-3', 'chr6': 'cv-3', 'chr8': 'cv-4', 'chr19': 'cv-4', 'chr12': 'cv-5', 'chr2': 'cv-5', 'chrX': 'cv-6', 'chr7': 'cv-6', 'chr20': 'cv-7', 'chr3': 'cv-7', 'chr4': 'cv-8', 'chr15': 'cv-10', 'chr10': 'cv-9', 'chr11': 'cv-11'}
# {'chr12': 87, 'chr11': 753, 'chr17': 543, 'chr2': 320, 'chr3': 257, 'chr7': 285, 'chr16': 699, 'chr19': 345, 'chr22': 518, 'chr6': 352, 'chr1': 391, 'chr10': 163, 'chr8': 79, 'chrX': 89, 'chr20': 96, 'chr14': 55, 'chr5': 73, 'chr15': 221, 'chr4': 97, 'chr9': 64, 'chr21': 53}
# Pancreas.GTEx Ovary.GTEx
# 16
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# ['chr12', 'chr22', 'chr6', 'chr9', 'chr8', 'chr2', 'chr1', 'chr4', 'chr3', 'chr15', 'chr7', 'chr11', 'chr10', 'chr19', 'chr16', 'chr17']
# {'cv-0': 1, 'cv-8': 72, 'cv-1': 20, 'cv-7': 59, 'cv-2': 23, 'cv-6': 55, 'cv-3': 25, 'cv-5': 45, 'cv-4': 32, 'cv-9': 85, 'cv-10': 91, 'cv-11': 358}
# {'chr12': 'cv-0', 'chr3': 'cv-8', 'chr22': 'cv-1', 'chr4': 'cv-7', 'chr6': 'cv-2', 'chr1': 'cv-6', 'chr9': 'cv-3', 'chr2': 'cv-5', 'chr8': 'cv-4', 'chr15': 'cv-9', 'chr7': 'cv-10', 'chr17': 'cv-11'}
# {'chr17': 358, 'chr3': 72, 'chr16': 191, 'chr1': 55, 'chr19': 134, 'chr8': 32, 'chr11': 98, 'chr7': 91, 'chr10': 119, 'chr6': 23, 'chr2': 45, 'chr9': 25, 'chr22': 20, 'chr4': 59, 'chr15': 85, 'chr12': 1}
# Pancreas.GTEx Stomach.GTEx
# 22
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# ['ch
# {'chr3': 180, 'chr16': 636, 'chrX': 6, 'chr17': 556, 'chr7': 277, 'chr5': 102, 'chr19': 220, 'chr1': 332, 'chr6': 456, 'chr11': 289, 'chr2': 339, 'chr12': 49, 'chr14': 135, 'chr9': 114, 'chr10': 32, 'chr18': 21, 'chr20': 22, 'chr22': 179, 'chr13': 13, 'chr15': 234, 'chr4': 48, 'chr21': 76}
# Liver.GTEx Stomach.GTEx
# 21
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# ['chrX', 'chr20', 'chr10', 'chr4', 'chr8', 'chr14', 'chr9', 'chr21', 'chr12', 'chr3', 'chr15', 'chr19', 'chr5', 'chr2', 'chr22', 'chr7', 'chr6', 'chr17', 'chr1', 'chr16', 'chr11']
# {'cv-0': 421, 'cv-1': 419, 'cv-2': 428, 'cv-3': 328, 'cv-4': 317, 'cv-5': 286, 'cv-6': 290, 'cv-7': 249, 'cv-8': 97, 'cv-10': 130, 'cv-9': 129, 'cv-11': 460}
# {'chrX': 'cv-0', 'chr1': 'cv-0', 'chr20': 'cv-1', 'chr17': 'cv-1', 'chr10': 'cv-2', 'chr6': 'cv-2', 'chr4': 'cv-3', 'chr7': 'cv-3', 'chr8': 'cv-4', 'chr22': 'cv-4', 'chr14': 'cv-5', 'chr2': 'cv-5', 'chr9': 'cv-6', 'chr5': 'cv-6', 'chr21': 'cv-7', 'chr19': 'cv-7', 'chr12': 'cv-8', 'chr15': 'cv-10', 'chr3': 'cv-9', 'chr11': 'cv-11'}
# {'chr2': 222, 'chr17': 397, 'chr16': 459, 'chr7': 277, 'chr19': 169, 'chr1': 418, 'chr6': 386, 'chr11': 460, 'chr8': 58, 'chr5': 218, 'chr12': 97, 'chr14': 64, 'chr22': 259, 'chr9': 72, 'chr10': 42, 'chr3': 129, 'chr20': 22, 'chrX': 3, 'chr15': 130, 'chr4': 51, 'chr21': 80}

# %%
##calculate F1 for tissues
f1data = pd.DataFrame(columns = ["SampleBENGI","SampleMSIMI", "F1_Score_MIMSI", "NumRows"])

for samplebengi in samplelistbengitissue:
    for samplehic in samplelisthictissue:
        if samplebengi != samplehic :
            test = pd.read_csv('/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/'+
                               samplebengi +
                               'BENGI_'
                               + samplehic
                               + 'MIMSI.csv', 
                         header=0, sep=' ')
            print(list(test))
            test=test.fillna(0)
            test['distance'] =test['distance'].abs()
            lr_f1, resultcv  = CVF1results(com, best_params, test)
            numrows = len(test)
            #Dataframe for the current sample  
            f1data1 = pd.DataFrame()
            f1data1['SampleBENGI'] = [samplebengi]*12
            f1data1['SampleMSIMI'] = [samplehic]*12
            f1data1['F1_Score_MIMSI'] = resultcv
            f1data1['NumRows'] = [numrows]*12
            # Concatenate with big dataframe
            print(f1data1)
            f1data1.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/CENTRE_final_training/F1scoresAcrossCT/'+
                           samplebengi +
                           '_' +
                           samplehic +
                           '_f1scores.csv')
            f1data = pd.concat([f1data, f1data1], ignore_index = True)
            

f1data.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/CENTRE_final_training/F1scoresAcrossCT/F1scoresTissues.csv')
# Out:
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.200
# 0.24242424242424238
# [0.08333333333333334, 0.30769230769230765, 1.0, 0.2, 0.5, 0.0, 0.30769230769230765, 0.0, 0.0, 0.0, 0.4, 0.28571428571428575]
# Distance:auc=0.197
#    SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Colon.GTEx  Ovary.GTEx        0.083333     1343
# 1   Colon.GTEx  Ovary.GTEx        0.307692     1343
# 2   Colon.GTEx  Ovary.GTEx        1.000000     1343
# 3   Colon.GTEx  Ovary.GTEx        0.200000     1343
# 4   Colon.GTEx  Ovary.GTEx        0.500000     1343
# 5   Colon.GTEx  Ovary.GTEx        0.000000     1343
# 6   Colon.GTEx  Ovary.GTEx        0.307692     1343
# 7   Colon.GTEx  Ovary.GTEx        0.000000     1343
# 8   Colon.GTEx  Ovary.GTEx        0.000000     1343
# 9   Colon.GTEx  Ovary.GTEx        0.000000     1343
# 10  Colon.GTEx  Ovary.GTEx        0.400000     1343
# 11  Colon.GTEx  Ovary.GTEx        0.285714     1343
# /scratch/local/ipykernel_99999/1479858290.py:31: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   f1data = pd.concat([f1data, f1data1], ignore_index = True)
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.168
# 0.2699055330634278
# [0.22033898305084748, 0.20000000000000004, 0.20689655172413793, 0.24, 0.11320754716981134, 0.25000000000000006, 0.39252336448598124, 0.27272727272727276, 0.5333333333333333, 0.2816901408450704, 0.3333333333333333, 0.32352941176470584]
# Distance:auc=0.197
#    SampleBENGI    SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Colon.GTEx  Pancreas.GTEx        0.220339     5540
# 1   Colon.GTEx  Pancreas.GTEx        0.200000     5540
# 2   Colon.GTEx  Pancreas.GTEx        0.206897     5540
# 3   Colon.GTEx  Pancreas.GTEx        0.240000     5540
# 4   Colon.GTEx  Pancreas.GTEx        0.113208     5540
# 5   Colon.GTEx  Pancreas.GTEx        0.250000     5540
# 6   Colon.GTEx  Pancreas.GTEx        0.392523     5540
# 7   Colon.GTEx  Pancreas.GTEx        0.272727     5540
# 8   Colon.GTEx  Pancreas.GTEx        0.533333     5540
# 9   Colon.GTEx  Pancreas.GTEx        0.281690     5540
# 10  Colon.GTEx  Pancreas.GTEx        0.333333     5540
# 11  Colon.GTEx  Pancreas.GTEx        0.323529     5540
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.144
# 0.23228346456692917
# [0.16091954022988503, 0.23880597014925373, 0.27692307692307694, 0.5116279069767442, 0.12, 0.2828282828282828, 0.22988505747126436, 0.16, 0.24657534246575344, 0.26530612244897955, 0.16129032258064516, 0.2580645161290322]
# Distance:auc=0.197
#    SampleBENGI   SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Colon.GTEx  Stomach.GTEx        0.160920     6801
# 1   Colon.GTEx  Stomach.GTEx        0.238806     6801
# 2   Colon.GTEx  Stomach.GTEx        0.276923     6801
# 3   Colon.GTEx  Stomach.GTEx        0.511628     6801
# 4   Colon.GTEx  Stomach.GTEx        0.120000     6801
# 5   Colon.GTEx  Stomach.GTEx        0.282828     6801
# 6   Colon.GTEx  Stomach.GTEx        0.229885     6801
# 7   Colon.GTEx  Stomach.GTEx        0.160000     6801
# 8   Colon.GTEx  Stomach.GTEx        0.246575     6801
# 9   Colon.GTEx  Stomach.GTEx        0.265306     6801
# 10  Colon.GTEx  Stomach.GTEx        0.161290     6801
# 11  Colon.GTEx  Stomach.GTEx        0.258065     6801
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.152
# 0.25
# [0.16666666666666666, 0.3076923076923077, 0.6666666666666666, 0.0, 0.4, 0.0, 0.2, 0.28571428571428575, 0.0, 0.6666666666666666, 0.4, 0.4444444444444444]
# Distance:auc=0.197
#    SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx  Colon.GTEx        0.166667     1343
# 1   Ovary.GTEx  Colon.GTEx        0.307692     1343
# 2   Ovary.GTEx  Colon.GTEx        0.666667     1343
# 3   Ovary.GTEx  Colon.GTEx        0.000000     1343
# 4   Ovary.GTEx  Colon.GTEx        0.400000     1343
# 5   Ovary.GTEx  Colon.GTEx        0.000000     1343
# 6   Ovary.GTEx  Colon.GTEx        0.200000     1343
# 7   Ovary.GTEx  Colon.GTEx        0.285714     1343
# 8   Ovary.GTEx  Colon.GTEx        0.000000     1343
# 9   Ovary.GTEx  Colon.GTEx        0.666667     1343
# 10  Ovary.GTEx  Colon.GTEx        0.400000     1343
# 11  Ovary.GTEx  Colon.GTEx        0.444444     1343
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# /home/lopez_s/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.142
# 0.1923076923076923
# [0.14814814814814814, 0.0, 0.2857142857142857, 0.0, 0.26666666666666666, 0.4, 0.25, 0.18181818181818182, 0.18181818181818182, 0.33333333333333337, 0.3636363636363636, 0.0]
# Distance:auc=0.197
#    SampleBENGI    SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx  Pancreas.GTEx        0.148148     1408
# 1   Ovary.GTEx  Pancreas.GTEx        0.000000     1408
# 2   Ovary.GTEx  Pancreas.GTEx        0.285714     1408
# 3   Ovary.GTEx  Pancreas.GTEx        0.000000     1408
# 4   Ovary.GTEx  Pancreas.GTEx        0.266667     1408
# 5   Ovary.GTEx  Pancreas.GTEx        0.400000     1408
# 6   Ovary.GTEx  Pancreas.GTEx        0.250000     1408
# 7   Ovary.GTEx  Pancreas.GTEx        0.181818     1408
# 8   Ovary.GTEx  Pancreas.GTEx        0.181818     1408
# 9   Ovary.GTEx  Pancreas.GTEx        0.333333     1408
# 10  Ovary.GTEx  Pancreas.GTEx        0.363636     1408
# 11  Ovary.GTEx  Pancreas.GTEx        0.000000     1408
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# /home/lopez_s/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.110
# 0.21818181818181817
# [0.2162162162162162, 0.0, 0.5, 0.16666666666666669, 0.0, 0.0, 0.0, 0.2857142857142857, 0.0, 0.8571428571428571, 0.0, 0.0]
# Distance:auc=0.197
#    SampleBENGI   SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Ovary.GTEx  Stomach.GTEx        0.216216     1257
# 1   Ovary.GTEx  Stomach.GTEx        0.000000     1257
# 2   Ovary.GTEx  Stomach.GTEx        0.500000     1257
# 3   Ovary.GTEx  Stomach.GTEx        0.166667     1257
# 4   Ovary.GTEx  Stomach.GTEx        0.000000     1257
# 5   Ovary.GTEx  Stomach.GTEx        0.000000     1257
# 6   Ovary.GTEx  Stomach.GTEx        0.000000     1257
# 7   Ovary.GTEx  Stomach.GTEx        0.285714     1257
# 8   Ovary.GTEx  Stomach.GTEx        0.000000     1257
# 9   Ovary.GTEx  Stomach.GTEx        0.857143     1257
# 10  Ovary.GTEx  Stomach.GTEx        0.000000     1257
# 11  Ovary.GTEx  Stomach.GTEx        0.000000     1257
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.193
# 0.2762557077625571
# [0.1732283464566929, 0.1276595744680851, 0.24324324324324326, 0.2105263157894737, 0.29411764705882354, 0.36619718309859156, 0.3025210084033613, 0.3448275862068966, 0.4705882352941177, 0.37209302325581395, 0.32499999999999996, 0.3287671232876712]
# Distance:auc=0.197
#       SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx  Colon.GTEx        0.173228     5540
# 1   Pancreas.GTEx  Colon.GTEx        0.127660     5540
# 2   Pancreas.GTEx  Colon.GTEx        0.243243     5540
# 3   Pancreas.GTEx  Colon.GTEx        0.210526     5540
# 4   Pancreas.GTEx  Colon.GTEx        0.294118     5540
# 5   Pancreas.GTEx  Colon.GTEx        0.366197     5540
# 6   Pancreas.GTEx  Colon.GTEx        0.302521     5540
# 7   Pancreas.GTEx  Colon.GTEx        0.344828     5540
# 8   Pancreas.GTEx  Colon.GTEx        0.470588     5540
# 9   Pancreas.GTEx  Colon.GTEx        0.372093     5540
# 10  Pancreas.GTEx  Colon.GTEx        0.325000     5540
# 11  Pancreas.GTEx  Colon.GTEx        0.328767     5540
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# /home/lopez_s/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.201
# 0.2840909090909091
# [0.16666666666666666, 0.0, 0.5714285714285715, 0.2727272727272727, 0.39999999999999997, 0.5714285714285715, 0.25, 0.3157894736842105, 0.0, 0.0, 0.7692307692307693, 0.15384615384615385]
# Distance:auc=0.197
#       SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx  Ovary.GTEx        0.166667     1408
# 1   Pancreas.GTEx  Ovary.GTEx        0.000000     1408
# 2   Pancreas.GTEx  Ovary.GTEx        0.571429     1408
# 3   Pancreas.GTEx  Ovary.GTEx        0.272727     1408
# 4   Pancreas.GTEx  Ovary.GTEx        0.400000     1408
# 5   Pancreas.GTEx  Ovary.GTEx        0.571429     1408
# 6   Pancreas.GTEx  Ovary.GTEx        0.250000     1408
# 7   Pancreas.GTEx  Ovary.GTEx        0.315789     1408
# 8   Pancreas.GTEx  Ovary.GTEx        0.000000     1408
# 9   Pancreas.GTEx  Ovary.GTEx        0.000000     1408
# 10  Pancreas.GTEx  Ovary.GTEx        0.769231     1408
# 11  Pancreas.GTEx  Ovary.GTEx        0.153846     1408
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.198
# 0.27609890109890106
# [0.2247191011235955, 0.26016260162601623, 0.35294117647058826, 0.21739130434782605, 0.3816793893129771, 0.21965317919075145, 0.11382113821138212, 0.3709677419354839, 0.34693877551020413, 0.22972972972972971, 0.3333333333333333, 0.3125]
# Distance:auc=0.197
#       SampleBENGI   SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Pancreas.GTEx  Stomach.GTEx        0.224719     8563
# 1   Pancreas.GTEx  Stomach.GTEx        0.260163     8563
# 2   Pancreas.GTEx  Stomach.GTEx        0.352941     8563
# 3   Pancreas.GTEx  Stomach.GTEx        0.217391     8563
# 4   Pancreas.GTEx  Stomach.GTEx        0.381679     8563
# 5   Pancreas.GTEx  Stomach.GTEx        0.219653     8563
# 6   Pancreas.GTEx  Stomach.GTEx        0.113821     8563
# 7   Pancreas.GTEx  Stomach.GTEx        0.370968     8563
# 8   Pancreas.GTEx  Stomach.GTEx        0.346939     8563
# 9   Pancreas.GTEx  Stomach.GTEx        0.229730     8563
# 10  Pancreas.GTEx  Stomach.GTEx        0.333333     8563
# 11  Pancreas.GTEx  Stomach.GTEx        0.312500     8563
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.143
# 0.24803149606299216
# [0.19148936170212766, 0.2644628099173554, 0.3098591549295775, 0.2926829268292683, 0.3, 0.30434782608695654, 0.24489795918367346, 0.19999999999999998, 0.17142857142857146, 0.23157894736842105, 0.14925373134328357, 0.288659793814433]
# Distance:auc=0.197
#      SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Stomach.GTEx  Colon.GTEx        0.191489     6801
# 1   Stomach.GTEx  Colon.GTEx        0.264463     6801
# 2   Stomach.GTEx  Colon.GTEx        0.309859     6801
# 3   Stomach.GTEx  Colon.GTEx        0.292683     6801
# 4   Stomach.GTEx  Colon.GTEx        0.300000     6801
# 5   Stomach.GTEx  Colon.GTEx        0.304348     6801
# 6   Stomach.GTEx  Colon.GTEx        0.244898     6801
# 7   Stomach.GTEx  Colon.GTEx        0.200000     6801
# 8   Stomach.GTEx  Colon.GTEx        0.171429     6801
# 9   Stomach.GTEx  Colon.GTEx        0.231579     6801
# 10  Stomach.GTEx  Colon.GTEx        0.149254     6801
# 11  Stomach.GTEx  Colon.GTEx        0.288660     6801
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# /home/lopez_s/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.227
# 0.2831858407079646
# [0.25, 0.0, 0.4, 0.2, 0.13333333333333333, 0.2857142857142857, 0.6666666666666666, 0.3333333333333333, 0.0, 0.6666666666666666, 0.5, 0.0]
# Distance:auc=0.197
#      SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Stomach.GTEx  Ovary.GTEx        0.250000     1257
# 1   Stomach.GTEx  Ovary.GTEx        0.000000     1257
# 2   Stomach.GTEx  Ovary.GTEx        0.400000     1257
# 3   Stomach.GTEx  Ovary.GTEx        0.200000     1257
# 4   Stomach.GTEx  Ovary.GTEx        0.133333     1257
# 5   Stomach.GTEx  Ovary.GTEx        0.285714     1257
# 6   Stomach.GTEx  Ovary.GTEx        0.666667     1257
# 7   Stomach.GTEx  Ovary.GTEx        0.333333     1257
# 8   Stomach.GTEx  Ovary.GTEx        0.000000     1257
# 9   Stomach.GTEx  Ovary.GTEx        0.666667     1257
# 10  Stomach.GTEx  Ovary.GTEx        0.500000     1257
# 11  Stomach.GTEx  Ovary.GTEx        0.000000     1257
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ...
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.178
# 0.2460456942003515
# [0.225, 0.25, 0.34146341463414637, 0.25641025641025644, 0.21276595744680848, 0.2807017543859649, 0.20408163265306123, 0.23076923076923073, 0.21052631578947364, 0.13333333333333333, 0.2424242424242424, 0.34615384615384615]
# Distance:auc=0.197
#    SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Liver.GTEx  Colon.GTEx        0.225000     3597
# 1   Liver.GTEx  Colon.GTEx        0.250000     3597
# 2   Liver.GTEx  Colon.GTEx        0.341463     3597
# 3   Liver.GTEx  Colon.GTEx        0.256410     3597
# 4   Liver.GTEx  Colon.GTEx        0.212766     3597
# 5   Liver.GTEx  Colon.GTEx        0.280702     3597
# 6   Liver.GTEx  Colon.GTEx        0.204082     3597
# 7   Liver.GTEx  Colon.GTEx        0.230769     3597
# 8   Liver.GTEx  Colon.GTEx        0.210526     3597
# 9   Liver.GTEx  Colon.GTEx        0.133333     3597
# 10  Liver.GTEx  Colon.GTEx        0.242424     3597
# 11  Liver.GTEx  Colon.GTEx        0.346154     3597
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.217
# 0.26760563380281693
# [0.14285714285714285, 1.0, 0.2222222222222222, 0.15384615384615385, 0.14285714285714285, 0.4, 0.0, 0.625, 0.13333333333333336, 0.25, 0.6666666666666666, 0.28571428571428575]
# Distance:auc=0.197
#    SampleBENGI SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Liver.GTEx  Ovary.GTEx        0.142857     1047
# 1   Liver.GTEx  Ovary.GTEx        1.000000     1047
# 2   Liver.GTEx  Ovary.GTEx        0.222222     1047
# 3   Liver.GTEx  Ovary.GTEx        0.153846     1047
# 4   Liver.GTEx  Ovary.GTEx        0.142857     1047
# 5   Liver.GTEx  Ovary.GTEx        0.400000     1047
# 6   Liver.GTEx  Ovary.GTEx        0.000000     1047
# 7   Liver.GTEx  Ovary.GTEx        0.625000     1047
# 8   Liver.GTEx  Ovary.GTEx        0.133333     1047
# 9   Liver.GTEx  Ovary.GTEx        0.250000     1047
# 10  Liver.GTEx  Ovary.GTEx        0.666667     1047
# 11  Liver.GTEx  Ovary.GTEx        0.285714     1047
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys(['cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.158
# 0.24751066856330015
# [0.13461538461538458, 0.1686746987951807, 0.30434782608695654, 0.42857142857142855, 0.19354838709677416, 0.35714285714285715, 0.3333333333333333, 0.37333333333333335, 0.1951219512195122, 0.2608695652173913, 0.1951219512195122, 0.19607843137254904]
# Distance:auc=0.197
#    SampleBENGI    SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Liver.GTEx  Pancreas.GTEx        0.134615     4316
# 1   Liver.GTEx  Pancreas.GTEx        0.168675     4316
# 2   Liver.GTEx  Pancreas.GTEx        0.304348     4316
# 3   Liver.GTEx  Pancreas.GTEx        0.428571     4316
# 4   Liver.GTEx  Pancreas.GTEx        0.193548     4316
# 5   Liver.GTEx  Pancreas.GTEx        0.357143     4316
# 6   Liver.GTEx  Pancreas.GTEx        0.333333     4316
# 7   Liver.GTEx  Pancreas.GTEx        0.373333     4316
# 8   Liver.GTEx  Pancreas.GTEx        0.195122     4316
# 9   Liver.GTEx  Pancreas.GTEx        0.260870     4316
# 10  Liver.GTEx  Pancreas.GTEx        0.195122     4316
# 11  Liver.GTEx  Pancreas.GTEx        0.196078     4316
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y', 'CVnew', 'CV']
# cv-11
# ['cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-0
# ['cv-11', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-5
# ['cv-11', 'cv-0', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-10
# ['cv-11', 'cv-0', 'cv-5', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-7
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-2
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-1
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-9', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-9
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-8', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-8
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-3', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-3
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-4', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-4
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-6']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# cv-6
# ['cv-11', 'cv-0', 'cv-5', 'cv-10', 'cv-7', 'cv-2', 'cv-1', 'cv-9', 'cv-8', 'cv-3', 'cv-4']
# dict_keys([0, 'cv-0', 'cv-1', 'cv-10', 'cv-11', 'cv-2', 'cv-3', 'cv-4', 'cv-5', 'cv-6', 'cv-7', 'cv-8', 'cv-9'])
# xgboost HiC 12 fold CV:auc=0.179
# 0.25806451612903225
# [0.275, 0.21428571428571427, 0.32, 0.15384615384615385, 0.09302325581395349, 0.3846153846153846, 0.32432432432432434, 0.13333333333333333, 0.2857142857142857, 0.16666666666666669, 0.25, 0.2641509433962264]
# Distance:auc=0.197
#    SampleBENGI   SampleMSIMI  F1_Score_MIMSI  NumRows
# 0   Liver.GTEx  Stomach.GTEx        0.275000     4013
# 1   Liver.GTEx  Stomach.GTEx        0.214286     4013
# 2   Liver.GTEx  Stomach.GTEx        0.320000     4013
# 3   Liver.GTEx  Stomach.GTEx        0.153846     4013
# 4   Liver.GTEx  Stomach.GTEx        0.093023     4013
# 5   Liver.GTEx  Stomach.GTEx        0.384615     4013
# 6   Liver.GTEx  Stomach.GTEx        0.324324     4013
# 7   Liver.GTEx  Stomach.GTEx        0.133333     4013
# 8   Liver.GTEx  Stomach.GTEx        0.285714     4013
# 9   Liver.GTEx  Stomach.GTEx        0.166667     4013
# 10  Liver.GTEx  Stomach.GTEx        0.250000     4013
# 11  Liver.GTEx  Stomach.GTEx        0.264151     4013

# %%
f1data.to_csv('/project/CRUP_scores/CENTRE_HiC/Training/CENTRE_final_training/f1_consensusLcL.csv')

# %%
test = pd.read_csv('/project/CRUP_scores/CENTRE_HiC/Training/BENGI_MSI_MI_acrossCT/'
                   "Colon.GTEx"+
                   'BENGI_'+
                   "GM12878.HiC"+
                   'MIMSI.csv', 
                   header=0, sep=' ')
print((list(test)))
# Out:
# ['gene_id1', 'gene_id', 'symbol38', 'symbol19', 'pair', 'pair19', 'label', 'CV', 'EP_prob_enh.1', 'EP_prob_enh.2', 'EP_prob_enh.3', 'EP_prob_enh.4', 'EP_prob_enh.5', 'EP_prob_gene.1', 'EP_prob_gene.2', 'EP_prob_gene.3', 'EP_prob_gene.4', 'EP_prob_gene.5', 'PP_prob_enh.1', 'PP_prob_enh.2', 'PP_prob_enh.3', 'PP_prob_enh.4', 'PP_prob_enh.5', 'PP_prob_gene.1', 'PP_prob_gene.2', 'PP_prob_gene.3', 'PP_prob_gene.4', 'PP_prob_gene.5', 'distance', 'cor_CRUP', 'combined_tests', 'reg_dist_enh', 'norm_reg_dist_enh', 'reg_dist_prom', 'norm_reg_dist_prom', 'RNA_seq', 'min_insulation', 'mean_switch_intensity', 'chr.x', 'chr.y']
